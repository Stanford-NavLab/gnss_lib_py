# %% [markdown]
# # Copy

# %%
import numpy as np
from gnss_lib_py.parsers.measurement import Measurement

# %% [markdown]
# Create an empty NavData class instantiation

# %%
empty_nav_data = Measurement()
print(type(empty_nav_data))

# %% [markdown]
# # Delete

# %%
print("Delete tutorial")
